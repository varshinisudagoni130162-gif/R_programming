# %% [markdown]
# <a href="https://colab.research.google.com/github/varshinisudagoni130162-gif/R_programming/blob/main/DMS_practical_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a<-5
print(a)
# Out:
# [1] 5

# %%
a<-15
b<-20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# [1] 35
# [1] -5
# [1] 300
# [1] 0.75

# %%
name<-"varshu"
class(name)
# Out:
# [1] "character"

# %%
a<-5
b<-10L
c<-"ammu"
d<-TRUE
print(class(a))
print(class(b))
print(class(c))
print(class(d))
# Out:
# [1] "numeric"
# [1] "integer"
# [1] "character"
# [1] "logical"

# %%
student_data<-data.frame(
  id= c(1,2,3,4),
  name =c("priya","hari","kavya","manu"),
  age= c(16,17,18,19)
)
print(student_data)
# Out:
#   id  name age
# 1  1 priya  16
# 2  2  hari  17
# 3  3 kavya  18
# 4  4  manu  19

# %%
a<- c(1,2,3,4)
b<- c(3,4,5,6)
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# [1]  4  6  8 10
# [1] -2 -2 -2 -2
# [1]  3  8 15 24
# [1] 0.3333333 0.5000000 0.6000000 0.6666667

# %%
student_data<-data.frame(
  ID = c(1,2,3,4),
  Name = c("Priya","lucky","varshu","vardhan"),
  Age = c(22,24,19,18),
  Marks = c(98,86,78,88)
)
print(student_data)
# Out:
#   ID    Name Age Marks
# 1  1   Priya  22    98
# 2  2   lucky  24    86
# 3  3  varshu  19    78
# 4  4 vardhan  18    88

# %%
arr<-array(1:6,dim=c(2,3))
print(arr)

#Functions
print(dim(arr))
print(length(arr))
print(str(arr))
# Out:
#      [,1] [,2] [,3]
# [1,]    1    3    5
# [2,]    2    4    6
# [1] 2 3
# [1] 6
#  int [1:2, 1:3] 1 2 3 4 5 6
# NULL

# %%
arr1<-array(1:12,dim=c(3,2,2))
print(arr1)
# Out:
# , , 1
#
#      [,1] [,2]
# [1,]    1    4
# [2,]    2    5
# [3,]    3    6
#
# , , 2
#
#      [,1] [,2]
# [1,]    7   10
# [2,]    8   11
# [3,]    9   12

# %%
arr<-array(
  1:12,
  dim=c(3,2,2),
  dimnames=list(
    c("R1","R2","R3"),
    c("C1","C2"),
    c("M1","M2")
  )
)
print(arr)
# Out:
# , , M1
#
#    C1 C2
# R1  1  4
# R2  2  5
# R3  3  6
#
# , , M2
#
#    C1 C2
# R1  7 10
# R2  8 11
# R3  9 12

# %%
x<-c(1,2,3,4)
y<-c(2,4,6,9)
plot(x,y,
  type="l",
  main="Simple Line Plot",
  xlab="Days",
  ylab="Sales"
  )
# Out:
# Plot with title “Simple Line Plot”
